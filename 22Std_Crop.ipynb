# %%
import cv2
import os
import glob
import random
import shutil
import numpy as np

# %%
# Function to crop the image based on specific coordinates
def crop_image(image, height_percentage=0.6):
    h, w = image.shape[:2]
    new_height = int(h * height_percentage)
    cropped_image = image[:new_height, :]
    return cropped_image

# Function to process all images in a directory recursively
def process_directory(input_dir, output_dir, height_percentage, num_images=None):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    all_image_paths = []
    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                all_image_paths.append(os.path.join(root, file))
    
    if num_images:
        all_image_paths = random.sample(all_image_paths, min(num_images, len(all_image_paths)))
    
    for image_path in all_image_paths:
        print(f"Processing: {image_path}")
        
        # Load the image
        image = cv2.imread(image_path)
        
        if image is None:
            print(f"Skipping image {image_path} due to loading error.")
            continue
        
        # Crop the image to keep only the top 60%
        cropped_image = crop_image(image, height_percentage)
        
        # Construct the output file path
        relative_path = os.path.relpath(image_path, input_dir)
        save_path = os.path.join(output_dir, relative_path)
        save_dir = os.path.dirname(save_path)
        
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
        # Save the cropped image
        cv2.imwrite(save_path, cropped_image)
        print(f"Processed and saved: {save_path}")

# Define input and output directories
input_dir = r'E:\Output_images\Covid-precrop'  # Update this path to your input images directory
output_dir = r'E:\Output_images\Covid-postrop'  # Update this path to your desired output directory for processed images

# Define the height percentage to keep (e.g., top 60%)
height_percentage = 0.6  # Keep the top 60% of the image

# Number of images to select (set to None to process all images)
num_images = None  # Adjust this number based on your computational capacity or set to None to process all images

# Process all images in the input directory recursively
process_directory(input_dir, output_dir, height_percentage, num_images)
# Out:
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_001.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_001.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_002.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_002.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_003.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_003.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_004.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_004.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_005.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_005.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_006.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_006.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_007.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_007.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_008.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_008.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_009.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_009.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_010.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_010.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_011.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_011.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_012.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_012.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_013.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_013.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_014.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_014.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_015.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_015.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_016.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_016.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_017.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_017.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_018.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_018.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_019.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_019.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_020.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_020.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_021.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_021.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_022.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_022.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_023.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_023.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_024.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_024.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_025.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_025.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_026.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_026.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_027.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_027.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_028.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_028.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_029.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_029.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_030.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_030.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_031.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_031.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_032.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_032.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_033.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_033.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_034.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_034.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_035.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_035.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_036.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_036.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_037.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_037.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_038.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_038.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_039.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_039.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_040.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_040.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_041.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_041.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_042.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_042.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_043.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_043.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_044.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_044.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_045.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_045.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_046.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_046.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_047.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_047.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_048.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_048.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_049.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_049.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_050.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_050.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_051.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_051.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_052.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_052.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_053.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_053.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_054.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_054.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_055.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_055.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_056.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_056.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_057.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_057.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_058.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_058.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_059.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_059.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_060.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_060.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_061.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_061.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_062.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_062.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_063.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_063.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_064.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_064.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_065.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_065.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_066.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_066.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_067.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_067.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_068.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_068.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_069.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_069.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_070.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_070.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_071.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_071.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_072.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_072.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_073.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_073.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_074.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_074.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_075.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_075.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_076.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_076.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_077.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_077.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_078.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_078.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_079.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_079.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_080.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_080.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_081.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_081.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_082.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_082.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_083.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_083.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_084.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_084.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_085.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_085.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_086.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_086.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_087.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_087.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_088.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_088.jpg
# Processing: E:\Output_images\Covid-precrop\Binder1_Page_089.jpg
# Processed and saved: E:\Output_images\Covid-postrop\Binder1_Page_089.jpg

# %% [markdown]
# Crop top 10%

# %%
import cv2
import os
import glob
import random
import numpy as np

# Function to crop the image based on specific coordinates
def crop_image(image, height_percentage=0.1):
    h, w = image.shape[:2]
    new_y = int(h * height_percentage)
    cropped_image = image[new_y:, :]
    return cropped_image

# Function to process all images in a directory recursively
def process_directory(input_dir, output_dir, height_percentage, num_images=None):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    all_image_paths = []
    for root, _, files in os.walk(input_dir):
        for file in files:
            if file.lower().endswith(('.jpg', '.jpeg', '.png', '.bmp')):
                all_image_paths.append(os.path.join(root, file))
    
    if num_images:
        all_image_paths = random.sample(all_image_paths, min(num_images, len(all_image_paths)))
    
    for image_path in all_image_paths:
        print(f"Processing: {image_path}")
        
        # Load the image
        image = cv2.imread(image_path)
        
        if image is None:
            print(f"Skipping image {image_path} due to loading error.")
            continue
        
        # Crop the image to remove the top 10%
        cropped_image = crop_image(image, height_percentage)
        
        # Construct the output file path
        relative_path = os.path.relpath(image_path, input_dir)
        save_path = os.path.join(output_dir, relative_path)
        save_dir = os.path.dirname(save_path)
        
        if not os.path.exists(save_dir):
            os.makedirs(save_dir)
        
        # Save the cropped image
        cv2.imwrite(save_path, cropped_image)
        print(f"Processed and saved: {save_path}")

# Define input and output directories
input_dir = r'E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)'  # Update this path to your input images directory
output_dir = r'E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop'  # Update this path to your desired output directory for processed images

# Define the height percentage to crop (e.g., top 10%)
height_percentage = 0.1  # Crop the top 10% of the image

# Number of images to select (set to None to process all images)
num_images = None  # Adjust this number based on your computational capacity or set to None to process all images

# Process all images in the input directory recursively
process_directory(input_dir, output_dir, height_percentage, num_images)
# Out:
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (1).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (1).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (10).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (10).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (100).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (100).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (101).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (101).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (102).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (102).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (103).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (103).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (104).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (104).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (105).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (105).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (106).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (106).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (107).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (107).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (108).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (108).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (109).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (109).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (11).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (11).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (110).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (110).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (111).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (111).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (112).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (112).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (113).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (113).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (114).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (114).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (115).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (115).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (116).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (116).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (117).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (117).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (118).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (118).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (119).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (119).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (12).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (12).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (120).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (120).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (121).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (121).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (122).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (122).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (123).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (123).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (124).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (124).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (125).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (125).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (126).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (126).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (127).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (127).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (128).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (128).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (129).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (129).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (13).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (13).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (130).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (130).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (131).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (131).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (132).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (132).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (133).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (133).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (134).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (134).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (135).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (135).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (136).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (136).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (137).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (137).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (138).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (138).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (139).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (139).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (14).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (14).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (140).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (140).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (141).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (141).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (142).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (142).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (143).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (143).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (144).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (144).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (145).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (145).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (146).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (146).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (147).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (147).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (148).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (148).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (149).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (149).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (15).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (15).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (150).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (150).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (151).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (151).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (152).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (152).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (153).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (153).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (154).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (154).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (155).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (155).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (156).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (156).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (157).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (157).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (158).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (158).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (159).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (159).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (16).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (16).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (160).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (160).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (161).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (161).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (162).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (162).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (163).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (163).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (164).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (164).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (165).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (165).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (166).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (166).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (167).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (167).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (168).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (168).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (169).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (169).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (17).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (17).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (170).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (170).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (171).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (171).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (172).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (172).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (173).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (173).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (174).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (174).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (175).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (175).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (176).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (176).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (177).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (177).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (178).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (178).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (179).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (179).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (18).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (18).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (180).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (180).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (19).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (19).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (2).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (2).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (20).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (20).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (21).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (21).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (22).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (22).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (23).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (23).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (24).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (24).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (25).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (25).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (26).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (26).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (27).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (27).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (28).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (28).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (29).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (29).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (3).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (3).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (30).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (30).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   (31).jpg
# Processed and saved: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)_Crop\HB   (31).jpg
# Processing: E:\Output_images\ECG Images of Patient that have abnormal heart beats (546)\HB   